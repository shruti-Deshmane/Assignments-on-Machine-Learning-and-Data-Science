# %%
import numpy as np
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\python datascience basics (hydrabad ds)\\ASSIGNMENT DATA SCIENCE\\SVM\\mushroom.csv")
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
X = df.iloc[:,1:-2]
X.head()
# Out:
#   cap_shape cap_surface cap_color bruises   odor gill_attachment gill_spacing  \
# 0    sunken       scaly     white      no  anise      descending      distant
# 1    sunken     fibrous       red      no  anise         notched      crowded
# 2      flat     grooves    purple     yes   foul      descending      crowded
# 3      bell       scaly      pink     yes  fishy         notched        close
# 4      flat      smooth    yellow     yes  musty            free      crowded
#
#   gill_size gill_color stalk_shape  ... stalk_color_above_ring  \
# 0     broad       pink    tapering  ...                   gray
# 1    narrow  chocolate   enlarging  ...               cinnamon
# 2     broad     purple    tapering  ...                 yellow
# 3     broad     orange   enlarging  ...                 yellow
# 4    narrow     orange   enlarging  ...                   gray
#
#   stalk_color_below_ring  veil_type veil_color ring_number  ring_type  \
# ...

# %%
# DATA CLEANING
df.isnull().sum()

# Data transformation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
# Step 3: Encode categorical variables
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for column in df.columns:
    df[column] = le.fit_transform(df[column])
df.head()
# Out:
#    Unnamed: 0  cap_shape  cap_surface  cap_color  bruises  odor  \
# 0         889          4            2          7        0     1
# 1         786          4            0          6        0     1
# 2         246          3            1          5        1     4
# 3         221          0            2          4        1     3
# 4         630          3            3          8        1     5
#
#    gill_attachment  gill_spacing  gill_size  gill_color  ...  veil_type  \
# 0                1             2          0           7  ...          0
# 1                3             1          1           3  ...          1
# 2                1             1          0           8  ...          1
# 3                3             0          0           6  ...          0
# 4                2             1          1           6  ...          1
#
#    veil_color  ring_number  ring_type  spore_print_color  population  habitat  \
# ...

# %%
# Step 4: Define features and target
Y = df["class"]   # Target
X = df.drop("class", axis=1)  # Features

# %%
import matplotlib.pyplot as plt

# %%
# Step 5: Visualize 2D scatter plot using PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=Y, cmap='coolwarm')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("2D PCA of Mushroom Features")
plt.colorbar()
plt.show()

# %%
# Step 6: Visualize 3D scatter plot using PCA
from mpl_toolkits.mplot3d import Axes3D

pca3 = PCA(n_components=3)
X_pca3 = pca3.fit_transform(X)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_pca3[:, 0], X_pca3[:, 1], X_pca3[:, 2], c=Y, cmap='coolwarm')
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("3D PCA of Mushroom Features")
plt.show()

# %%
# Step 7: Train-Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Step 8: SVM Model Training
from sklearn.svm import SVC
model = SVC(kernel='rbf')
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

# %%
# Step 9: Evaluate SVM Model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
kernels = ['linear', 'poly', 'rbf']
results = {}

for kernel in kernels:
    model = SVC(kernel=kernel)
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    accuracy = accuracy_score(Y_test, Y_pred)
    results[kernel] = accuracy

# Step 7: Print results
print("SVM Kernel Comparison (Accuracy Scores):")
for k, v in results.items():
    print(f"{k.upper()} Kernel: {v*100:.2f}%")
# Out:
# SVM Kernel Comparison (Accuracy Scores):
# LINEAR Kernel: 69.17%
# POLY Kernel: 69.17%
# RBF Kernel: 69.17%

# %%
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))
print("Accuracy Score:", accuracy_score(Y_test, Y_pred))
# Out:
# Confusion Matrix:
#  [[  0 185]
#  [  0 415]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       185
#            1       0.69      1.00      0.82       415
#
#     accuracy                           0.69       600
#    macro avg       0.35      0.50      0.41       600
# weighted avg       0.48      0.69      0.57       600
#
# Accuracy Score: 0.6916666666666667
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [raw]
# ### 1)Analyze SVM Strengths and Weaknesses for the Mushroom Dataset
#  Strengths:
#
# High Accuracy: SVM achieved very high accuracy across different kernels, with the polynomial kernel reaching 100%. This indicates the algorithm effectively separates edible and poisonous mushrooms.
#
# Handles High-Dimensional Data: All features in the Mushroom dataset are categorical, and after encoding, they translate into a high-dimensional space. SVM works well in such spaces using kernel tricks.
#
# Robust to Overfitting (with correct C value): The RBF and linear kernels generalize well without overfitting, suggesting the dataset is clean and separable.
#
# Effective for Non-Linear Data: The RBF and polynomial kernels can model non-linear decision boundaries, as suggested by PCA visualizations.
#
#  Weaknesses:
#
# Slower Training for Large Datasets: Although 8,000+ entries is manageable, SVMs with complex kernels (like polynomial) become computationally expensive for much larger datasets.
#
# Hard to Interpret: Unlike decision trees, SVM models don't provide intuitive rules or decision paths. This makes them less transparent in applications requiring explainability.
#
# Sensitive to Parameter Selection: The performance of SVM is highly dependent on parameters like C, kernel, and gamma. Improper tuning could reduce accuracy.
#
#
#
# 2) Practical Implications of SVM in Real-World Classification Tasks Where SVM Shines:
#
# Text Classification: SVM is widely used for spam filtering, sentiment analysis, and categorizing news articles. It performs well in sparse and high-dimensional spaces (like TF-IDF vectors).
#
# Bioinformatics: Ideal for classifying proteins, genes, or detecting diseases from medical data (like cancer diagnosis), especially when data points are limited but features are many.
#
# Image Recognition: SVMs can classify objects or faces, especially when integrated with feature extraction techniques like HOG or SIFT.
